# %% [markdown]
# # First Steps with the OANDA API

# %% [markdown]
# ## Connecting to the API / Server

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.get_account_summary()
# Out:
# {'id': '101-004-22810993-001',
#  'alias': 'Primary',
#  'currency': 'GBP',
#  'balance': '100010.0',
#  'createdByUserID': 22810993,
#  'createdTime': '2022-07-17T14:43:56.881987200Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '0.0',
#  'resettablePL': '0.0',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.02',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '100010.0',
#  'marginUsed': '0.0',
#  'marginAvailable': '100010.0',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '100010.0',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '100010.0',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '4'}

# %%
api.account_type
# Out:
# 'practice'

# %%
api.account_id
# Out:
# '101-004-22810993-001'

# %%
api.get_instruments()
# Out:
# [('China H Shares', 'CHINAH_HKD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('USD/PLN', 'USD_PLN'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('EUR/USD', 'EUR_USD'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('USD/INR', 'USD_INR'),
#  ('USD/CAD', 'USD_CAD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('USD/DKK', 'USD_DKK'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('ZAR/JPY', 'ZAR_JPY'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('USD/JPY', 'USD_JPY'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('EUR/CZK', 'EUR_CZK'),
# ...

# %%
instr = api.get_instruments()

# %%
len(instr)
# Out:
# 125

# %%
instr[0]
# Out:
# ('China H Shares', 'CHINAH_HKD')

# %% [markdown]
# ## Getting Historical Data (Part 1)

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
# ...
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask) or 'B' (bid)
#
#     Returns
# ...
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
api.get_history(instrument = "GBP_USD", start = "2020-07-01", end = "2020-07-31",
                granularity = "D", price = "B")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   37864      True  1.23965  1.24896  1.23585
# 2020-07-01 21:00:00+00:00   37214      True  1.24681  1.25291  1.24552
# 2020-07-02 21:00:00+00:00   27110      True  1.24619  1.24855  1.24372
# 2020-07-05 21:00:00+00:00   32802      True  1.24676  1.25192  1.24575
# 2020-07-06 21:00:00+00:00   38646      True  1.24870  1.25912  1.24619
# 2020-07-07 21:00:00+00:00   41894      True  1.25411  1.26223  1.25078
# 2020-07-08 21:00:00+00:00   45988      True  1.26037  1.26688  1.25992
# 2020-07-09 21:00:00+00:00   36545      True  1.26040  1.26631  1.25659
# 2020-07-12 21:00:00+00:00   37124      True  1.26103  1.26652  1.25484
# 2020-07-13 21:00:00+00:00   45976      True  1.25550  1.25628  1.24790
# 2020-07-14 21:00:00+00:00   41311      True  1.25506  1.26487  1.25463
# 2020-07-15 21:00:00+00:00   39351      True  1.25790  1.26239  1.25191
# ...

# %%
df = api.get_history(instrument = "GBP_USD", start = "2020-07-01", end = "2020-07-31",
                granularity = "D", price = "B")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23 entries, 2020-06-30 21:00:00+00:00 to 2020-07-30 21:00:00+00:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   volume    23 non-null     int64
#  1   complete  23 non-null     bool
#  2   o         23 non-null     float64
#  3   h         23 non-null     float64
#  4   l         23 non-null     float64
#  5   c         23 non-null     float64
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 1.1 KB

# %%
api.get_history(instrument = "GBP_USD", start = "2020-07-01", end = "2020-07-01",
                granularity = "D", price = "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   37864      True  1.24025  1.24914  1.23606
#
#                                  c
# time
# 2020-06-30 21:00:00+00:00  1.24784

# %%
api.get_history(instrument = "GBP_USD", start = "2020-07-01", end = "2020-07-01",
                granularity = "D", price = "B")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   37864      True  1.23965  1.24896  1.23585
#
#                                  c
# time
# 2020-06-30 21:00:00+00:00  1.24724

# %% [markdown]
# ## Getting Historical Data (Part 2)

# %%
api.get_history("GBP_USD", "2020-08-03", "2020-08-05", "H1", "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-08-03 00:00:00+00:00    3682      True  1.31013  1.31086  1.30583
# 2020-08-03 01:00:00+00:00    2889      True  1.30763  1.30979  1.30662
# 2020-08-03 02:00:00+00:00    1598      True  1.30955  1.30955  1.30801
# 2020-08-03 03:00:00+00:00    1035      True  1.30852  1.30950  1.30825
# 2020-08-03 04:00:00+00:00     867      True  1.30942  1.30982  1.30900
# 2020-08-03 05:00:00+00:00    1106      True  1.30926  1.30967  1.30862
# 2020-08-03 06:00:00+00:00    2121      True  1.30943  1.30950  1.30560
# 2020-08-03 07:00:00+00:00    3088      True  1.30637  1.30867  1.30632
# 2020-08-03 08:00:00+00:00    2845      True  1.30771  1.31137  1.30764
# 2020-08-03 09:00:00+00:00    2826      True  1.31023  1.31038  1.30380
# 2020-08-03 10:00:00+00:00    3351      True  1.30439  1.30478  1.30131
# 2020-08-03 11:00:00+00:00    2130      True  1.30165  1.30344  1.30132
# ...

# %%
api.get_history("GBP_USD", "2020-08-03", "2020-08-05", "H12", "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-08-02 21:00:00+00:00   20981      True  1.30878  1.31137  1.30560
# 2020-08-03 09:00:00+00:00   28884      True  1.31023  1.31038  1.30058
# 2020-08-03 21:00:00+00:00   13504      True  1.30801  1.31088  1.30472
# 2020-08-04 09:00:00+00:00   28468      True  1.30702  1.30795  1.29824
# 2020-08-04 21:00:00+00:00   13338      True  1.30680  1.31244  1.30589
#
#                                  c
# time
# 2020-08-02 21:00:00+00:00  1.31024
# 2020-08-03 09:00:00+00:00  1.30781
# 2020-08-03 21:00:00+00:00  1.30698
# 2020-08-04 09:00:00+00:00  1.30741
# 2020-08-04 21:00:00+00:00  1.31023

# %%
api.get_history("GBP_USD", "2020-08-03", "2020-08-05", "M1", "A")
# Out:
# c:\Users\lilaa\anaconda3\envs\Sheffield\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = pd.concat([data,batch],axis=0)
# c:\Users\lilaa\anaconda3\envs\Sheffield\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = pd.concat([data,batch],axis=0)
#                            volume  complete        o        h        l  \
# time
# 2020-08-03 00:00:00+00:00      43      True  1.31013  1.31026  1.31000
# 2020-08-03 00:01:00+00:00      28      True  1.31022  1.31062  1.31022
# 2020-08-03 00:02:00+00:00      36      True  1.31061  1.31086  1.31061
# 2020-08-03 00:03:00+00:00      16      True  1.31071  1.31081  1.31067
# 2020-08-03 00:04:00+00:00      41      True  1.31064  1.31064  1.31007
# ...

# %%
api.get_history("GBP_USD", "2020-08-03", "2020-08-04", "S5", "A")
# Out:
# c:\Users\lilaa\anaconda3\envs\Sheffield\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = pd.concat([data,batch],axis=0)
# c:\Users\lilaa\anaconda3\envs\Sheffield\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = pd.concat([data,batch],axis=0)
# c:\Users\lilaa\anaconda3\envs\Sheffield\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = pd.concat([data,batch],axis=0)
# c:\Users\lilaa\anaconda3\envs\Sheffield\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
api.get_instruments()
# Out:
# [('China H Shares', 'CHINAH_HKD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('USD/PLN', 'USD_PLN'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('EUR/USD', 'EUR_USD'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('USD/INR', 'USD_INR'),
#  ('USD/CAD', 'USD_CAD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('USD/DKK', 'USD_DKK'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('ZAR/JPY', 'ZAR_JPY'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('USD/JPY', 'USD_JPY'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('EUR/CZK', 'EUR_CZK'),
# ...

# %%
api.get_history("SPX500_USD", "2020-08-03", "2020-08-04", "H1", "A")
# Out:
#                            volume  complete       o       h       l       c
# time
# 2020-08-03 00:00:00+00:00    2094      True  3272.8  3276.1  3267.0  3273.5
# 2020-08-03 01:00:00+00:00    1916      True  3273.8  3279.6  3271.5  3277.8
# 2020-08-03 02:00:00+00:00     843      True  3278.1  3278.1  3270.5  3271.8
# 2020-08-03 03:00:00+00:00     482      True  3272.3  3273.8  3269.5  3270.3
# 2020-08-03 04:00:00+00:00     368      True  3270.6  3271.8  3268.5  3271.8
# 2020-08-03 05:00:00+00:00     499      True  3272.0  3275.6  3270.0  3272.4
# 2020-08-03 06:00:00+00:00     743      True  3272.0  3272.8  3267.3  3270.0
# 2020-08-03 07:00:00+00:00    1717      True  3270.3  3272.3  3263.0  3272.0
# 2020-08-03 08:00:00+00:00    1160      True  3272.3  3275.9  3264.3  3267.8
# 2020-08-03 09:00:00+00:00    1085      True  3267.5  3275.3  3266.0  3275.0
# 2020-08-03 10:00:00+00:00    1078      True  3274.5  3288.8  3273.8  3288.0
# ...

# %% [markdown]
# ## Streaming high-frequency real-time Data

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.stream_data('EUR_USD')
# Out:
# 2022-07-18T04:41:49.907543189Z 1.00889 1.00903
# 2022-07-18T04:42:17.021647343Z 1.00888 1.00903
# 2022-07-18T04:42:17.508834906Z 1.00881 1.00899
# 2022-07-18T04:42:17.822144984Z 1.00881 1.00897
# 2022-07-18T04:42:20.787315315Z 1.00881 1.00898
# 2022-07-18T04:42:20.926948720Z 1.00881 1.00897
# 2022-07-18T04:42:21.824358701Z 1.00882 1.00896
# 2022-07-18T04:42:24.398343606Z 1.00875 1.00892
# 2022-07-18T04:42:24.599197249Z 1.00876 1.00891
# 2022-07-18T04:42:25.070492850Z 1.00878 1.00893
# 2022-07-18T04:42:32.538463168Z 1.00877 1.00893
# 2022-07-18T04:42:33.139962125Z 1.00877 1.00892
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Dessertation\Oanda_firststeps.ipynb Cell 34 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Dessertation/Oanda_firststeps.ipynb#ch0000033?line=0'>1</a> api.stream_data('EUR_USD')
#
# ...

# %%
api.stop_stream()

# %% [markdown]
# ## Creating Orders and Executing Trades

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.create_order(instrument = "EUR_USD", units = 100000, sl_distance= 0.1)
# Out:
#  {'id': '8', 'time': '2022-07-18T04:42:51.516564846Z', 'userID': 22810993, 'accountID': '101-004-22810993-001', 'batchID': '7', 'requestID': '42983453730521950', 'type': 'ORDER_FILL', 'orderID': '7', 'instrument': 'EUR_USD', 'units': '100000.0', 'gainQuoteHomeConversionFactor': '0.837411687877', 'lossQuoteHomeConversionFactor': '0.845827885746', 'price': 1.00892, 'fullVWAP': 1.00892, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.00875, 'liquidity': '10000000'}], 'asks': [{'price': 1.00892, 'liquidity': '10000000'}], 'closeoutBid': 1.00875, 'closeoutAsk': 1.00892}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '100010.0', 'tradeOpened': {'tradeID': '8', 'units': '100000.0', 'price': 1.00892, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '7.1538', 'initialMarginRequired': '2827.4364'}, 'halfSpreadCost': '7.1538'}

# %%
api.create_order(instrument = "EUR_USD", units = -100000, sl_distance= 0.1)
# Out:
#  {'id': '11', 'time': '2022-07-18T04:43:03.696569817Z', 'userID': 22810993, 'accountID': '101-004-22810993-001', 'batchID': '10', 'requestID': '42983453780863866', 'type': 'ORDER_FILL', 'orderID': '10', 'instrument': 'EUR_USD', 'units': '-100000.0', 'gainQuoteHomeConversionFactor': '0.837425784946', 'lossQuoteHomeConversionFactor': '0.845842124493', 'price': 1.00876, 'fullVWAP': 1.00876, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.00876, 'liquidity': '10000000'}], 'asks': [{'price': 1.00893, 'liquidity': '10000000'}], 'closeoutBid': 1.00876, 'closeoutAsk': 1.00893}, 'reason': 'MARKET_ORDER', 'pl': '-13.5335', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '99996.4665', 'tradesClosed': [{'tradeID': '8', 'units': '-100000.0', 'price': 1.00876, 'realizedPL': '-13.5335', 'financing': '0.0', 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '7.1539'}], 'halfSpreadCost': '7.1539'}

# %%
api.get_account_summary()
# Out:
# {'id': '101-004-22810993-001',
#  'alias': 'Primary',
#  'currency': 'GBP',
#  'balance': '99996.4665',
#  'createdByUserID': 22810993,
#  'createdTime': '2022-07-17T14:43:56.881987200Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-13.5335',
#  'resettablePL': '-13.5335',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.02',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '99996.4665',
#  'marginUsed': '0.0',
#  'marginAvailable': '99996.4665',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '99996.4665',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '99996.4665',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '12'}

# %%
api.get_transactions(tid = 10)
# Out:
# [{'id': '11',
#   'time': '2022-07-18T04:43:03.696569817Z',
#   'userID': 22810993,
#   'accountID': '101-004-22810993-001',
#   'batchID': '10',
#   'requestID': '42983453780863866',
#   'type': 'ORDER_FILL',
#   'orderID': '10',
#   'instrument': 'EUR_USD',
#   'units': '-100000.0',
#   'gainQuoteHomeConversionFactor': '0.837425784946',
#   'lossQuoteHomeConversionFactor': '0.845842124493',
#   'price': 1.00876,
#   'fullVWAP': 1.00876,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.00876, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.00893, 'liquidity': '10000000'}],
#    'closeoutBid': 1.00876,
#    'closeoutAsk': 1.00893},
#   'reason': 'MARKET_ORDER',
#   'pl': '-13.5335',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99996.4665',
#   'tradesClosed': [{'tradeID': '8',
#     'units': '-100000.0',
#     'price': 1.00876,
#     'realizedPL': '-13.5335',
#     'financing': '0.0',
# ...

# %%
api.print_transactions(tid = 11-1)
# Out:
#    11 | 2022-07-18T04:43:03.696569817Z |   EUR_USD |    -100000.0 | -13.5335
